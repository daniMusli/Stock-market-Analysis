# %% [markdown]
# # DATASET For Stock Features As:
#
# ## Stock Price Action:
# Open, High, Low, Close, Adjust close ,Trade Volume
#
# ## Stock Probability analysis data:
# RSI, MACD, Bollinger, DMA, Volume Delta, Rate change
#
# ## economy data:
# Unemployment rate and Price index per Month
#
# ## News data:
# Last 100 News per each stock with analyzer of the good whether it's good or bad
#
# ## Analyzed stocks:
# - AAPl
# - AZN
# - BA
# - DIS
# - JPM
# - MSFT
# - NVDA
# - PFE
# - TSLA
# - WMT

# %%
# Import libraries
import yfinance as yf
import numpy as np
from stockstats import StockDataFrame as Sdf
import pandas as pd 
import quandl
import matplotlib
import matplotlib.pyplot as plt
import warnings
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
import os
import nltk
from pandas import read_csv
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from matplotlib.pyplot import figure

warnings.filterwarnings("ignore")
# download lexicon for analyzer
nltk.downloader.download('vader_lexicon')
# pass the processed data to the sentiment intensity analyzer 
vader = SentimentIntensityAnalyzer() # initiate the analyzer
warnings.filterwarnings("ignore")
# %matplotlib inline
quandl.ApiConfig.api_key = "GyzsN_xp1_FWKUyqZ4s5"
plt.style.use('fivethirtyeight')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\abdul\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %% [markdown]
# ## economy data:

# %%
unemployment = quandl.get(["FRED/UNRATE"],
    trim_start="2015-01-01", trim_end="2020-12-01", collapse = 'monthly')
unemployment.columns = ['Unemployment']
Price_index = quandl.get(["FRED/CUUR0000SA0R"],\
    trim_start="2020-02-01", trim_end="2020-12-01", collapse = 'monthly')
Price_index.columns = ['Consumer Price Index']

# %% [markdown]
# # analysis data:  (5 years Range)

# %% [markdown]
# ## Apple Ticker:

# %%
AAPL_data = yf.download('AAPL','2015-01-01','2020-12-01')
AAPL_data = AAPL_data.dropna()
AAPL_data=Sdf.retype(AAPL_data)
AAPL_data['macd']=AAPL_data['macd'] #macd s is 26 avr and h is 12 ave
AAPL_data['boll']=AAPL_data['boll'] #upper boll
AAPL_data['boll_lb']=AAPL_data['boll_lb'] #middle STD
AAPL_data['boll_lb']=AAPL_data['boll_lb'] #lower boll
AAPL_data['volume_delta']=AAPL_data['volume_delta'] #volume compared to yesterday
AAPL_data['dma']=AAPL_data['dma'] #diff between 10 and 50 moving avg
AAPL_data['open_-2_r'] = AAPL_data['open_-2_r']  #price change in rate

AAPL_data = pd.concat([Price_index,unemployment, AAPL_data], axis=1)
AAPL_data = AAPL_data.fillna(method='ffill')
AAPL_data = AAPL_data.fillna(method='bfill')
AAPL_data = AAPL_data.iloc[3:]
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# ## Astrazeneca Ticker:

# %%
AZN_data = yf.download('AZN','2015-01-01','2020-12-01')
AZN_data = AZN_data.dropna()
AZN_data=Sdf.retype(AZN_data)
AZN_data['macd']=AZN_data['macd'] #macd s is 26 avr and h is 12 ave
AZN_data['boll']=AZN_data['boll'] #upper boll
AZN_data['boll_lb']=AZN_data['boll_lb'] #middle STD
AZN_data['boll_lb']=AZN_data['boll_lb'] #lower boll
AZN_data['volume_delta']=AZN_data['volume_delta'] #volume compared to yesterday
AZN_data['dma']=AZN_data['dma'] #diff between 10 and 50 moving avg
AZN_data['open_-2_r'] = AZN_data['open_-2_r']  #price change in rate

AZN_data = pd.concat([Price_index,unemployment, AZN_data], axis=1)
AZN_data = AZN_data.fillna(method='ffill')
AZN_data = AZN_data.fillna(method='bfill')
AZN_data = AZN_data.iloc[3:]
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# ## Boeing Ticker:

# %%
BA_data = yf.download('BA','2015-01-01','2020-12-01')
BA_data = BA_data.dropna()
BA_data=Sdf.retype(BA_data)
BA_data['macd']=BA_data['macd'] #macd s is 26 avr and h is 12 ave
BA_data['boll']=BA_data['boll'] #upper boll
BA_data['boll_lb']=BA_data['boll_lb'] #middle STD
BA_data['boll_lb']=BA_data['boll_lb'] #lower boll
BA_data['volume_delta']=BA_data['volume_delta'] #volume compared to yesterday
BA_data['dma']=BA_data['dma'] #diff between 10 and 50 moving avg
BA_data['open_-2_r'] = BA_data['open_-2_r']  #price change in rate

BA_data = pd.concat([Price_index,unemployment, BA_data], axis=1)
BA_data = BA_data.fillna(method='ffill')
BA_data = BA_data.fillna(method='bfill')
BA_data = BA_data.iloc[3:]
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# ## Disney Ticker:

# %%
DIS_data = yf.download('DIS','2015-01-01','2020-12-01')
DIS_data = DIS_data.dropna()
DIS_data=Sdf.retype(DIS_data)
DIS_data['macd']=DIS_data['macd'] #macd s is 26 avr and h is 12 ave
DIS_data['boll']=DIS_data['boll'] #upper boll
DIS_data['boll_lb']=DIS_data['boll_lb'] #middle STD
DIS_data['boll_lb']=DIS_data['boll_lb'] #lower boll
DIS_data['volume_delta']=DIS_data['volume_delta'] #volume compared to yesterday
DIS_data['dma']=DIS_data['dma'] #diff between 10 and 50 moving avg
DIS_data['open_-2_r'] = DIS_data['open_-2_r']  #price change in rate

DIS_data = pd.concat([Price_index,unemployment, DIS_data], axis=1)
DIS_data = DIS_data.fillna(method='ffill')
DIS_data = DIS_data.fillna(method='bfill')
DIS_data = DIS_data.iloc[3:]
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# ## jp morgan Ticker:

# %%
JPM_data = yf.download('JPM','2015-01-01','2020-12-01')
JPM_data = JPM_data.dropna()
JPM_data=Sdf.retype(JPM_data)
JPM_data['macd']=JPM_data['macd'] #macd s is 26 avr and h is 12 ave
JPM_data['boll']=JPM_data['boll'] #upper boll
JPM_data['boll_lb']=JPM_data['boll_lb'] #middle STD
JPM_data['boll_lb']=JPM_data['boll_lb'] #lower boll
JPM_data['volume_delta']=JPM_data['volume_delta'] #volume compared to yesterday
JPM_data['dma']=JPM_data['dma'] #diff between 10 and 50 moving avg
JPM_data['open_-2_r'] = JPM_data['open_-2_r']  #price change in rate

JPM_data = pd.concat([Price_index,unemployment, JPM_data], axis=1)
JPM_data = JPM_data.fillna(method='ffill')
JPM_data = JPM_data.fillna(method='bfill')
JPM_data = JPM_data.iloc[3:]
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# ## Microsoft Ticker:

# %%
MSFT_data = yf.download('MSFT','2015-01-01','2020-12-01')
MSFT_data = MSFT_data.dropna()
MSFT_data=Sdf.retype(MSFT_data)
MSFT_data['macd']=MSFT_data['macd'] #macd s is 26 avr and h is 12 ave
MSFT_data['boll']=MSFT_data['boll'] #upper boll
MSFT_data['boll_lb']=MSFT_data['boll_lb'] #middle STD
MSFT_data['boll_lb']=MSFT_data['boll_lb'] #lower boll
MSFT_data['volume_delta']=MSFT_data['volume_delta'] #volume compared to yesterday
MSFT_data['dma']=MSFT_data['dma'] #diff between 10 and 50 moving avg
MSFT_data['open_-2_r'] = MSFT_data['open_-2_r']  #price change in rate

MSFT_data = pd.concat([Price_index,unemployment, MSFT_data], axis=1)
MSFT_data = MSFT_data.fillna(method='ffill')
MSFT_data = MSFT_data.fillna(method='bfill')
MSFT_data = MSFT_data.iloc[3:]
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# ## nvidia Ticker:

# %%
NVDA_data = yf.download('NVDA','2015-01-01','2020-12-01')
NVDA_data = NVDA_data.dropna()
NVDA_data=Sdf.retype(NVDA_data)
NVDA_data['macd']=NVDA_data['macd'] #macd s is 26 avr and h is 12 ave
NVDA_data['boll']=NVDA_data['boll'] #upper boll
NVDA_data['boll_lb']=NVDA_data['boll_lb'] #middle STD
NVDA_data['boll_lb']=NVDA_data['boll_lb'] #lower boll
NVDA_data['volume_delta']=NVDA_data['volume_delta'] #volume compared to yesterday
NVDA_data['dma']=NVDA_data['dma'] #diff between 10 and 50 moving avg
NVDA_data['open_-2_r'] = NVDA_data['open_-2_r']  #price change in rate

NVDA_data = pd.concat([Price_index,unemployment, NVDA_data], axis=1)
NVDA_data = NVDA_data.fillna(method='ffill')
NVDA_data = NVDA_data.fillna(method='bfill')
NVDA_data = NVDA_data.iloc[3:]
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# ## Pfizer  Ticker:

# %%
PFE_data = yf.download('PFE','2015-01-01','2020-12-01')
PFE_data = PFE_data.dropna()
PFE_data=Sdf.retype(PFE_data)
PFE_data['macd']=PFE_data['macd'] #macd s is 26 avr and h is 12 ave
PFE_data['boll']=PFE_data['boll'] #upper boll
PFE_data['boll_lb']=PFE_data['boll_lb'] #middle STD
PFE_data['boll_lb']=PFE_data['boll_lb'] #lower boll
PFE_data['volume_delta']=PFE_data['volume_delta'] #volume compared to yesterday
PFE_data['dma']=PFE_data['dma'] #diff between 10 and 50 moving avg
PFE_data['open_-2_r'] = PFE_data['open_-2_r']  #price change in rate

PFE_data = pd.concat([Price_index,unemployment, PFE_data], axis=1)
PFE_data = PFE_data.fillna(method='ffill')
PFE_data = PFE_data.fillna(method='bfill')
PFE_data = PFE_data.iloc[3:]
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# ## Tesla Ticker:

# %%
TSLA_data = yf.download('TSLA','2015-01-01','2020-12-01')
TSLA_data = TSLA_data.dropna()
TSLA_data=Sdf.retype(TSLA_data)
TSLA_data['macd']=TSLA_data['macd'] #macd s is 26 avr and h is 12 ave
TSLA_data['boll']=TSLA_data['boll'] #upper boll
TSLA_data['boll_lb']=TSLA_data['boll_lb'] #middle STD
TSLA_data['boll_lb']=TSLA_data['boll_lb'] #lower boll
TSLA_data['volume_delta']=TSLA_data['volume_delta'] #volume compared to yesterday
TSLA_data['dma']=TSLA_data['dma'] #diff between 10 and 50 moving avg
TSLA_data['open_-2_r'] = TSLA_data['open_-2_r']  #price change in rate

TSLA_data = pd.concat([Price_index,unemployment, TSLA_data], axis=1)
TSLA_data = TSLA_data.fillna(method='ffill')
TSLA_data = TSLA_data.fillna(method='bfill')
TSLA_data = TSLA_data.iloc[3:]
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# ## Walmart Ticker:

# %%
WMT_data = yf.download('WMT','2015-01-01','2020-12-01')
WMT_data = WMT_data.dropna()
WMT_data=Sdf.retype(WMT_data)
WMT_data['macd']=WMT_data['macd'] #macd s is 26 avr and h is 12 ave
WMT_data['boll']=WMT_data['boll'] #upper boll
WMT_data['boll_lb']=WMT_data['boll_lb'] #middle STD
WMT_data['boll_lb']=WMT_data['boll_lb'] #lower boll
WMT_data['volume_delta']=WMT_data['volume_delta'] #volume compared to yesterday
WMT_data['dma']=WMT_data['dma'] #diff between 10 and 50 moving avg
WMT_data['open_-2_r'] = WMT_data['open_-2_r']  #price change in rate

WMT_data = pd.concat([Price_index,unemployment, WMT_data], axis=1)
WMT_data = WMT_data.fillna(method='ffill')
WMT_data = WMT_data.fillna(method='bfill')
WMT_data = WMT_data.iloc[3:]
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# ## News data:

# %%
#os.chdir(r"C:\Users\Afify\Downloads\Stock Project")
#news_data = read_csv('news_analysis_processed.csv',header =0, parse_dates = ['date'],index_col=0,squeeze=True)
#news_data = pd.DataFrame(news_data)
news_data = pd.read_csv('news_analysis_processed.csv')

WMT_d  = yf.download('WMT','2020-11-25','2020-12-03')
TSLA_d = yf.download('TSLA','2020-11-25','2020-12-03')
PFE_d  = yf.download('PFE','2020-11-25','2020-12-03')
NVDA_d = yf.download('NVDA','2020-11-25','2020-12-03')
MSFT_d = yf.download('MSFT','2020-11-25','2020-12-03')
JPM_d  = yf.download('JPM','2020-11-25','2020-12-03')
DIS_d  = yf.download('DIS','2020-11-25','2020-12-03')
BA_d   = yf.download('BA','2020-11-25','2020-12-03')
AZN_d  = yf.download('AZN','2020-11-25','2020-12-03')
AAPL_d = yf.download('AAPL','2020-11-25','2020-12-03')

AZN = news_data.loc[news_data['ticker'] == "AZN"] 
AZN = AZN.reset_index(drop=True)
del AZN['ticker']
AZN = AZN.set_index('date')
AZN = AZN.groupby(['date']).mean()
AZN.index = pd.to_datetime(AZN.index)
AZN_d = pd.concat([AZN, AZN_d], axis=1)
AZN_d = AZN_d.fillna(0)



PFE = news_data.loc[news_data['ticker'] == "PFE"]
PFE = PFE.reset_index(drop=True)
del PFE['ticker']
PFE = PFE.set_index('date')
PFE = PFE.groupby(['date']).mean()
PFE.index = pd.to_datetime(PFE.index)
PFE_d = pd.concat([PFE, PFE_d], axis=1)
PFE_d = PFE_d.fillna(0)

AAPL = news_data.loc[news_data['ticker'] == "AAPL"]
AAPL = AAPL.reset_index(drop=True)
del AAPL['ticker']
AAPL = AAPL.set_index('date')
AAPL = AAPL.groupby(['date']).mean()
AAPL.index = pd.to_datetime(AAPL.index)
AAPL_d = pd.concat([AAPL, AAPL_d], axis=1)
AAPL_d =AAPL_d.fillna(0)

NVDA = news_data.loc[news_data['ticker'] == "NVDA"]
NVDA = NVDA.reset_index(drop=True)
del NVDA['ticker']
NVDA = NVDA.set_index('date')
NVDA = NVDA.groupby(['date']).mean()
NVDA.index = pd.to_datetime(NVDA.index)
NVDA_d = pd.concat([NVDA, NVDA_d], axis=1)
NVDA_d = NVDA_d.fillna(0)

MSFT = news_data.loc[news_data['ticker'] == "MSFT"]
MSFT = MSFT.reset_index(drop=True)
del MSFT['ticker']
MSFT = MSFT.set_index('date')
MSFT = MSFT.groupby(['date']).mean()
MSFT.index = pd.to_datetime(MSFT.index)
MSFT_d = pd.concat([MSFT, MSFT_d], axis=1)
MSFT_d = MSFT_d.fillna(0)

TSLA = news_data.loc[news_data['ticker'] == "TSLA"]
TSLA = TSLA.reset_index(drop=True)
del TSLA['ticker']
TSLA = TSLA.set_index('date')
TSLA = TSLA.groupby(['date']).mean()
TSLA.index = pd.to_datetime(TSLA.index)
TSLA_d = pd.concat([TSLA, TSLA_d], axis=1)
TSLA_d = TSLA_d.fillna(0)

JPM = news_data.loc[news_data['ticker'] == "JPM"]
del JPM['ticker']
JPM = JPM.reset_index(drop=True)
JPM = JPM.set_index('date')
JPM = JPM.groupby(['date']).mean()
JPM.index = pd.to_datetime(JPM.index)
JPM_d = pd.concat([JPM, JPM_d], axis=1)
JPM_d = JPM_d.fillna(0)

BA = news_data.loc[news_data['ticker'] == "BA"]
BA = BA.reset_index(drop=True)
del BA['ticker']
BA = BA.set_index('date')
BA = BA.groupby(['date']).mean()
BA.index = pd.to_datetime(BA.index)
BA_d = pd.concat([BA, BA_d], axis=1)
BA_d = BA_d.fillna(0)

WMT = news_data.loc[news_data['ticker'] == "WMT"]
WMT = WMT.reset_index(drop=True)
del WMT['ticker']
WMT = WMT.set_index('date')
WMT = WMT.groupby(['date']).mean()
WMT.index = pd.to_datetime(WMT.index)
WMT_d = pd.concat([WMT, WMT_d], axis=1)
WMT_d = WMT_d.fillna(0)

DIS = news_data.loc[news_data['ticker'] == "DIS"]
DIS = DIS.reset_index(drop=True)
del DIS['ticker']
DIS = DIS.set_index('date')
DIS = DIS.groupby(['date']).mean()
DIS.index = pd.to_datetime(DIS.index)
DIS_d = pd.concat([DIS, DIS_d], axis=1)
DIS_d = DIS_d.fillna(0)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
#Plot graph with 2 y axes
fig, ax1 = plt.subplots(figsize=(15,8))

#Plot bars
ax1.bar(AAPL_d.index,AAPL_d['news_value'] ,alpha=0.3)
ax1.set_xlabel('Date')

# Make the y-axis label and tick labels match the line color.
ax1.set_ylabel('News Score Value', color='b')
[tl.set_color('b') for tl in ax1.get_yticklabels()]

#Set up ax2 to be the second y axis with x shared
ax2 = ax1.twinx()
#Plot a line
ax2.plot(AAPL_d.index,AAPL_d['Adj Close'] , 'r-')

# Make the y-axis label and tick labels match the line color.
ax2.set_ylabel('Stock Value', color='r')
[tl.set_color('r') for tl in ax2.get_yticklabels()]

plt.show()

# %%
#Plot graph with 2 y axes
fig, ax1 = plt.subplots(figsize=(15,8))

#Plot bars
ax1.bar(WMT_d.index,WMT_d['news_value'] ,alpha=0.3)
ax1.set_xlabel('Date')

# Make the y-axis label and tick labels match the line color.
ax1.set_ylabel('News Score Value', color='b')
[tl.set_color('b') for tl in ax1.get_yticklabels()]

#Set up ax2 to be the second y axis with x shared
ax2 = ax1.twinx()
#Plot a line
ax2.plot(WMT_d.index,WMT_d['Adj Close'] , 'r-')

# Make the y-axis label and tick labels match the line color.
ax2.set_ylabel('Stock Value', color='r')
[tl.set_color('r') for tl in ax2.get_yticklabels()]

plt.show()

# %%
#Plot graph with 2 y axes
fig, ax1 = plt.subplots(figsize=(15,8))

#Plot bars
ax1.bar(TSLA_d.index,TSLA_d['news_value'] ,alpha=0.3)
ax1.set_xlabel('Date')

# Make the y-axis label and tick labels match the line color.
ax1.set_ylabel('News Score Value', color='b')
[tl.set_color('b') for tl in ax1.get_yticklabels()]

#Set up ax2 to be the second y axis with x shared
ax2 = ax1.twinx()
#Plot a line
ax2.plot(TSLA_d.index,TSLA_d['Adj Close'] , 'r-')

# Make the y-axis label and tick labels match the line color.
ax2.set_ylabel('Stock Value', color='r')
[tl.set_color('r') for tl in ax2.get_yticklabels()]

plt.show()

# %%
#Plot graph with 2 y axes
fig, ax1 = plt.subplots(figsize=(15,8))

#Plot bars
ax1.bar(PFE_d.index,PFE_d['news_value'] ,alpha=0.3)
ax1.set_xlabel('Date')

# Make the y-axis label and tick labels match the line color.
ax1.set_ylabel('News Score Value', color='b')
[tl.set_color('b') for tl in ax1.get_yticklabels()]

#Set up ax2 to be the second y axis with x shared
ax2 = ax1.twinx()
#Plot a line
ax2.plot(PFE_d.index,PFE_d['Adj Close'] , 'r-')

# Make the y-axis label and tick labels match the line color.
ax2.set_ylabel('Stock Value', color='r')
[tl.set_color('r') for tl in ax2.get_yticklabels()]

plt.show()

# %%
#Plot graph with 2 y axes
fig, ax1 = plt.subplots(figsize=(15,8))

#Plot bars
ax1.bar(NVDA_d.index,NVDA_d['news_value'] ,alpha=0.3)
ax1.set_xlabel('Date')

# Make the y-axis label and tick labels match the line color.
ax1.set_ylabel('News Score Value', color='b')
[tl.set_color('b') for tl in ax1.get_yticklabels()]

#Set up ax2 to be the second y axis with x shared
ax2 = ax1.twinx()
#Plot a line
ax2.plot(NVDA_d.index,NVDA_d['Adj Close'] , 'r-')

# Make the y-axis label and tick labels match the line color.
ax2.set_ylabel('Stock Value', color='r')
[tl.set_color('r') for tl in ax2.get_yticklabels()]

plt.show()

# %%
#Plot graph with 2 y axes
fig, ax1 = plt.subplots(figsize=(15,8))

#Plot bars
ax1.bar(MSFT_d.index,MSFT_d['news_value'] ,alpha=0.3)
ax1.set_xlabel('Date')

# Make the y-axis label and tick labels match the line color.
ax1.set_ylabel('News Score Value', color='b')
[tl.set_color('b') for tl in ax1.get_yticklabels()]

#Set up ax2 to be the second y axis with x shared
ax2 = ax1.twinx()
#Plot a line
ax2.plot(MSFT_d.index,MSFT_d['Adj Close'] , 'r-')

# Make the y-axis label and tick labels match the line color.
ax2.set_ylabel('Stock Value', color='r')
[tl.set_color('r') for tl in ax2.get_yticklabels()]

plt.show()

# %%
#Plot graph with 2 y axes
fig, ax1 = plt.subplots(figsize=(15,8))

#Plot bars
ax1.bar(JPM_d.index,JPM_d['news_value'] ,alpha=0.3)
ax1.set_xlabel('Date')

# Make the y-axis label and tick labels match the line color.
ax1.set_ylabel('News Score Value', color='b')
[tl.set_color('b') for tl in ax1.get_yticklabels()]

#Set up ax2 to be the second y axis with x shared
ax2 = ax1.twinx()
#Plot a line
ax2.plot(JPM_d.index,JPM_d['Adj Close'] , 'r-')

# Make the y-axis label and tick labels match the line color.
ax2.set_ylabel('Stock Value', color='r')
[tl.set_color('r') for tl in ax2.get_yticklabels()]

plt.show()

# %%
#Plot graph with 2 y axes
fig, ax1 = plt.subplots(figsize=(15,8))

#Plot bars
ax1.bar(DIS_d.index,DIS_d['news_value'] ,alpha=0.3)
ax1.set_xlabel('Date')

# Make the y-axis label and tick labels match the line color.
ax1.set_ylabel('News Score Value', color='b')
[tl.set_color('b') for tl in ax1.get_yticklabels()]

#Set up ax2 to be the second y axis with x shared
ax2 = ax1.twinx()
#Plot a line
ax2.plot(DIS_d.index,DIS_d['Adj Close'] , 'r-')

# Make the y-axis label and tick labels match the line color.
ax2.set_ylabel('Stock Value', color='r')
[tl.set_color('r') for tl in ax2.get_yticklabels()]

plt.show()

# %%
#Plot graph with 2 y axes
fig, ax1 = plt.subplots(figsize=(15,8))

#Plot bars
ax1.bar(BA_d.index,BA_d['news_value'] ,alpha=0.3)
ax1.set_xlabel('Date')

# Make the y-axis label and tick labels match the line color.
ax1.set_ylabel('News Score Value', color='b')
[tl.set_color('b') for tl in ax1.get_yticklabels()]

#Set up ax2 to be the second y axis with x shared
ax2 = ax1.twinx()
#Plot a line
ax2.plot(BA_d.index,BA_d['Adj Close'] , 'r-')

# Make the y-axis label and tick labels match the line color.
ax2.set_ylabel('Stock Value', color='r')
[tl.set_color('r') for tl in ax2.get_yticklabels()]

plt.show()

# %%
#Plot graph with 2 y axes
fig, ax1 = plt.subplots(figsize=(15,8))

#Plot bars
ax1.bar(AZN_d.index,AZN_d['news_value'] ,alpha=0.3)
ax1.set_xlabel('Date')

# Make the y-axis label and tick labels match the line color.
ax1.set_ylabel('News Score Value', color='b')
[tl.set_color('b') for tl in ax1.get_yticklabels()]

#Set up ax2 to be the second y axis with x shared
ax2 = ax1.twinx()
#Plot a line
ax2.plot(AZN_d.index,AZN_d['Adj Close'] , 'r-')

# Make the y-axis label and tick labels match the line color.
ax2.set_ylabel('Stock Value', color='r')
[tl.set_color('r') for tl in ax2.get_yticklabels()]

plt.show()
